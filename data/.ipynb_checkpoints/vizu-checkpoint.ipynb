# %%
import seaborn as sns
import pandas as pd

# %%
infile = 'train_users_2.csv'
df = pd.read_csv(infile)
df_bis = df[['gender', 'country_destination']].iloc[900:1000]

# %%
df_bis
# Out:
#         gender country_destination
# 900     FEMALE                 NDF
# 901  -unknown-                  US
# 902     FEMALE                  DE
# 903  -unknown-                 NDF
# 904  -unknown-                  US
# 905  -unknown-                  US
# 906  -unknown-                  IT
# 907     FEMALE                  ES
# 908  -unknown-                 NDF
# 909     FEMALE                  US
# 910     FEMALE                 NDF
# 911     FEMALE                 NDF
# 912  -unknown-                  GB
# 913  -unknown-                 NDF
# 914  -unknown-                  US
# 915  -unknown-                  US
# 916  -unknown-                  US
# 917       MALE                  US
# 918     FEMALE                 NDF
# 919     FEMALE                 NDF
# 920     FEMALE                  US
# 921     FEMALE                  US
# 922       MALE                  CA
# 923       MALE                 NDF
# 924  -unknown-                 NDF
# 925  -unknown-                 NDF
# ...

# %%
sns.pairplot(df_bis, dropna=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-6e8a9df6d7a0> in <module>()
# ----> 1 sns.pairplot(df_bis, dropna=False)
#
# /home/thiebaut/anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1581                     hue_order=hue_order, palette=palette,
#    1582                     diag_sharey=diag_sharey,
# -> 1583                     size=size, aspect=aspect, dropna=dropna, **grid_kws)
#    1584
#    1585     # Add the markers here as PairGrid has figured out how many levels of the
#
# /home/thiebaut/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, size, aspect, despine, dropna)
# ...

# %%
test = sns.load_dataset('iris')

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame
